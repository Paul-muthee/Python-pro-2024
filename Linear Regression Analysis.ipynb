# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
companies = pd.read_csv('C:/Users/HP 1040 G7 X360/Downloads/1000_Companies.csv')
X= companies.iloc[:, :-1].values
Y= companies.iloc[:, :4].values
print(companies)
# Out:
#      R&D Spend  Administration  Marketing Spend       State        Profit
# 0    165349.20      136897.800      471784.1000    New York  192261.83000
# 1    162597.70      151377.590      443898.5300  California  191792.06000
# 2    153441.51      101145.550      407934.5400     Florida  191050.39000
# 3    144372.41      118671.850      383199.6200    New York  182901.99000
# 4    142107.34       91391.770      366168.4200     Florida  166187.94000
# ..         ...             ...              ...         ...           ...
# 995   54135.00      118451.999      173232.6695  California   95279.96251
# 996  134970.00      130390.080      329204.0228  California  164336.60550
# 997  100275.47      241926.310      227142.8200  California  413956.48000
# 998  128456.23      321652.140      281692.3200  California  333962.19000
# 999  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [1000 rows x 5 columns]

# %%
# Data Visualisation
# Building correlation matrix
# Create a DataFrame
companies = pd.DataFrame(companies)

# Select only numeric columns
numeric_companies = companies.select_dtypes(include=[float, int])

# Check if the DataFrame is correctly defined
print(numeric_companies)

# Building correlation matrix
correlation_matrix = numeric_companies.corr()

# Plotting the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()
# Out:
#      R&D Spend  Administration  Marketing Spend        Profit
# 0    165349.20      136897.800      471784.1000  192261.83000
# 1    162597.70      151377.590      443898.5300  191792.06000
# 2    153441.51      101145.550      407934.5400  191050.39000
# 3    144372.41      118671.850      383199.6200  182901.99000
# 4    142107.34       91391.770      366168.4200  166187.94000
# ..         ...             ...              ...           ...
# 995   54135.00      118451.999      173232.6695   95279.96251
# 996  134970.00      130390.080      329204.0228  164336.60550
# 997  100275.47      241926.310      227142.8200  413956.48000
# 998  128456.23      321652.140      281692.3200  333962.19000
# 999  161181.72      270939.860      295442.1700  476485.43000
#
# [1000 rows x 4 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Assuming you already have the 'companies' DataFrame loaded
# If needed, you would load your dataset here. For example:
companies = pd.read_csv('C:/Users/HP 1040 G7 X360/Downloads/1000_Companies.csv')

# Prepare the data
X = companies[['R&D Spend', 'Administration', 'Marketing Spend']]
y = companies['Profit']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Perform linear regression
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')

# Display the coefficients
coefficients = pd.DataFrame(model.coef_, X.columns, columns=['Coefficient'])
print(coefficients)
# Out:
# Mean Squared Error: 191134724.7297224
# R-squared: 0.9117375294964101
#                  Coefficient
# R&D Spend           0.527378
# Administration      0.845828
# Marketing Spend     0.106641
